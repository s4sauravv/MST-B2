# %%
#Logistic Regression Project 
#Continue 
#Predict Diabetest

# %%
#Import necessary Libraries
import numpy as np
import pandas as pd

#For data Visualization
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns


import warnings
warnings.filterwarnings('ignore')

# %%
#Import Dataset
data=pd.read_csv('https://raw.githubusercontent.com/s4sauravv/Datasets/main/diabetes.csv')
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# # Features
#
#
#
#
# Pregnancies
#
#
#
#
# Glucose
#
#
#
#
# BloodPressure
#
#
#
# SkinThickness
#
#
#
# Insulin
#
#
#
# BMI
#
#
#
# DiabetesPedigreeFunction
#
#
#
#
# Age	Outcome
#
#
# # Label
#
#
#
# Outcome
#
#
#
# - 0- Normal
#
# - 1-Daibetes

# %%
data.shape
# Out:
# (768, 9)

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
#Good , there is no null values
#But there is 0 . we have to resolve this
# Lets see in Distribution Plot

# %%
plt.figure(figsize=(20,15),facecolor='orange')
plotnumber = 1
for column in data:
    if plotnumber <=9:
        ax=plt.subplot(3,3,plotnumber)
        sns.distplot(data[column])
        plt.xlabel(column,fontsize=20)
    plotnumber +=1
plt.tight_layout()

# %%
#There is 0 values in this featur(Glucose	BloodPressure	SkinThickness	Insulin	     BMI)
#We have to remove that.

# %%
data['Glucose']=data['Glucose'].replace(0,data['Glucose'].mean())

# %%
data['BloodPressure']=data['BloodPressure'].replace(0,data['BloodPressure'].mean())
data['SkinThickness']=data['SkinThickness'].replace(0,data['SkinThickness'].mean())
data['Insulin']=data['Insulin'].replace(0,data['Insulin'].mean())
data['BMI']=data['BMI'].replace(0,data['BMI'].mean())

# %%
#Lest Plot Again and see problems in dataset

# %%
plt.figure(figsize=(20,15),facecolor='orange')
plotnumber = 1
for column in data:
    if plotnumber <=9:
        ax=plt.subplot(3,3,plotnumber)
        sns.distplot(data[column])
        plt.xlabel(column,fontsize=20)
    plotnumber +=1
plt.tight_layout()

# %%
#Now its Good Looking 
#But i think there is outliers
#Lets go And Fix this also
#Lets see by Boxplot

# %%
plt.figure(figsize=(20,15),facecolor='blue')
plotnumber=1
for column in data:
    if plotnumber <=9:
        plt.subplot(3,3,plotnumber)
        ax=sns.boxplot(data=data[column])
        plt.xlabel(column)
    plotnumber +=1
plt.show()

# %%
#There are Lots of outliersd
data.describe()
# we have to remove outliers
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  121.681605      72.254807      26.606479  118.660163
# std       3.369578   30.436016      12.115932       9.631241   93.080358
# min       0.000000   44.000000      24.000000       7.000000   14.000000
# 25%       1.000000   99.750000      64.000000      20.536458   79.799479
# 50%       3.000000  117.000000      72.000000      23.000000   79.799479
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    32.450805                  0.471876   33.240885    0.348958
# std      6.875374                  0.331329   11.760232    0.476951
# ...

# %%
#Lets Handle Outliers

# %%
q1=data.quantile (0.25)

# %%
q3=data.quantile (0.75)

# %%
iqr=q3-q1

# %%
print(q1)
print(q3)
print(iqr)
# Out:
# Pregnancies                  1.000000
# Glucose                     99.750000
# BloodPressure               64.000000
# SkinThickness               20.536458
# Insulin                     79.799479
# BMI                         27.500000
# DiabetesPedigreeFunction     0.243750
# Age                         24.000000
# Outcome                      0.000000
# Name: 0.25, dtype: float64
# Pregnancies                   6.00000
# Glucose                     140.25000
# BloodPressure                80.00000
# SkinThickness                32.00000
# Insulin                     127.25000
# BMI                          36.60000
# DiabetesPedigreeFunction      0.62625
# Age                          41.00000
# Outcome                       1.00000
# Name: 0.75, dtype: float64
# Pregnancies                  5.000000
# Glucose                     40.500000
# BloodPressure               16.000000
# SkinThickness               11.463542
# Insulin                     47.450521
# ...

# %%
#Pregnancies
preg=q3.Pregnancies +(1.5*iqr.Pregnancies)
index=np.where(data['Pregnancies'] > preg)
data=data.drop(data.index[index])
print(data.shape)
data.reset_index()
# Out:
# (764, 9)
#      index  Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin  \
# 0        0            6    148.0           72.0      35.000000   79.799479
# 1        1            1     85.0           66.0      29.000000   79.799479
# 2        2            8    183.0           64.0      20.536458   79.799479
# 3        3            1     89.0           66.0      23.000000   94.000000
# 4        4            0    137.0           40.0      35.000000  168.000000
# ..     ...          ...      ...            ...            ...         ...
# 759    763           10    101.0           76.0      48.000000  180.000000
# 760    764            2    122.0           70.0      27.000000   79.799479
# 761    765            5    121.0           72.0      23.000000  112.000000
# 762    766            1    126.0           60.0      20.536458   79.799479
# 763    767            1     93.0           70.0      31.000000   79.799479
#
#       BMI  DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
#BloodPressure
bp=q3.BloodPressure +(1.5*iqr.BloodPressure)
index=np.where(data['BloodPressure']>bp)
data=data.drop(data.index[index])
print(data.shape)
data.reset_index()
# Out:
# (754, 9)
#      index  Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin  \
# 0        0            6    148.0           72.0      35.000000   79.799479
# 1        1            1     85.0           66.0      29.000000   79.799479
# 2        2            8    183.0           64.0      20.536458   79.799479
# 3        3            1     89.0           66.0      23.000000   94.000000
# 4        4            0    137.0           40.0      35.000000  168.000000
# ..     ...          ...      ...            ...            ...         ...
# 749    763           10    101.0           76.0      48.000000  180.000000
# 750    764            2    122.0           70.0      27.000000   79.799479
# 751    765            5    121.0           72.0      23.000000  112.000000
# 752    766            1    126.0           60.0      20.536458   79.799479
# 753    767            1     93.0           70.0      31.000000   79.799479
#
#       BMI  DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
#For lower Outliers

# %%
#BloodPressure
bp=q1.BloodPressure -(1.5*iqr.BloodPressure)
index=np.where(data['BloodPressure']<bp)
data=data.drop(data.index[index])
print(data.shape)
data.reset_index()
# Out:
# (750, 9)
#      index  Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin  \
# 0        0            6    148.0           72.0      35.000000   79.799479
# 1        1            1     85.0           66.0      29.000000   79.799479
# 2        2            8    183.0           64.0      20.536458   79.799479
# 3        3            1     89.0           66.0      23.000000   94.000000
# 4        4            0    137.0           40.0      35.000000  168.000000
# ..     ...          ...      ...            ...            ...         ...
# 745    763           10    101.0           76.0      48.000000  180.000000
# 746    764            2    122.0           70.0      27.000000   79.799479
# 747    765            5    121.0           72.0      23.000000  112.000000
# 748    766            1    126.0           60.0      20.536458   79.799479
# 749    767            1     93.0           70.0      31.000000   79.799479
#
#       BMI  DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
#For Upper Outliers

# %%
#SkinThickness
sk=q3.SkinThickness +(1.5 * iqr.SkinThickness)
index=np.where(data['SkinThickness']>sk)
data=data.drop(data.index[index])
print(data.shape)
data.reset_index()
# Out:
# (738, 9)
#      index  Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin  \
# 0        0            6    148.0           72.0      35.000000   79.799479
# 1        1            1     85.0           66.0      29.000000   79.799479
# 2        2            8    183.0           64.0      20.536458   79.799479
# 3        3            1     89.0           66.0      23.000000   94.000000
# 4        4            0    137.0           40.0      35.000000  168.000000
# ..     ...          ...      ...            ...            ...         ...
# 733    763           10    101.0           76.0      48.000000  180.000000
# 734    764            2    122.0           70.0      27.000000   79.799479
# 735    765            5    121.0           72.0      23.000000  112.000000
# 736    766            1    126.0           60.0      20.536458   79.799479
# 737    767            1     93.0           70.0      31.000000   79.799479
#
#       BMI  DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
#Insulin
ins=iqr.Insulin + (1.5*iqr.Insulin)
index=np.where(data['Insulin']>ins)
data=data.drop(data.index[index])
print(data.shape)
data.reset_index()
# Out:
# (535, 9)
#      index  Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin  \
# 0        0            6    148.0           72.0      35.000000   79.799479
# 1        1            1     85.0           66.0      29.000000   79.799479
# 2        2            8    183.0           64.0      20.536458   79.799479
# 3        3            1     89.0           66.0      23.000000   94.000000
# 4        5            5    116.0           74.0      20.536458   79.799479
# ..     ...          ...      ...            ...            ...         ...
# 530    762            9     89.0           62.0      20.536458   79.799479
# 531    764            2    122.0           70.0      27.000000   79.799479
# 532    765            5    121.0           72.0      23.000000  112.000000
# 533    766            1    126.0           60.0      20.536458   79.799479
# 534    767            1     93.0           70.0      31.000000   79.799479
#
#       BMI  DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
#BMI
bm=q3.BMI * (1.5 + iqr.BMI)
index=np.where(data['BMI']>bm)
data=data.drop(data.index[index])
print(data.shape)
data.reset_index()
# Out:
# (535, 9)
#      index  Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin  \
# 0        0            6    148.0           72.0      35.000000   79.799479
# 1        1            1     85.0           66.0      29.000000   79.799479
# 2        2            8    183.0           64.0      20.536458   79.799479
# 3        3            1     89.0           66.0      23.000000   94.000000
# 4        5            5    116.0           74.0      20.536458   79.799479
# ..     ...          ...      ...            ...            ...         ...
# 530    762            9     89.0           62.0      20.536458   79.799479
# 531    764            2    122.0           70.0      27.000000   79.799479
# 532    765            5    121.0           72.0      23.000000  112.000000
# 533    766            1    126.0           60.0      20.536458   79.799479
# 534    767            1     93.0           70.0      31.000000   79.799479
#
#       BMI  DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
#DiabetesPedigreeFunction
dbs=q3.DiabetesPedigreeFunction + (1.5 *iqr.DiabetesPedigreeFunction)
index=np.where(data['DiabetesPedigreeFunction']>dbs)
data=data.drop(data.index[index])
print(data.shape)
data.reset_index()
# Out:
# (518, 9)
#      index  Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin  \
# 0        0            6    148.0           72.0      35.000000   79.799479
# 1        1            1     85.0           66.0      29.000000   79.799479
# 2        2            8    183.0           64.0      20.536458   79.799479
# 3        3            1     89.0           66.0      23.000000   94.000000
# 4        5            5    116.0           74.0      20.536458   79.799479
# ..     ...          ...      ...            ...            ...         ...
# 513    762            9     89.0           62.0      20.536458   79.799479
# 514    764            2    122.0           70.0      27.000000   79.799479
# 515    765            5    121.0           72.0      23.000000  112.000000
# 516    766            1    126.0           60.0      20.536458   79.799479
# 517    767            1     93.0           70.0      31.000000   79.799479
#
#       BMI  DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
#I think now in dataset there is no problem and we are good to go.
#Lets plot categorial plot (stripplot)
# And check the relationship

# %%
x=data.drop(columns=['Outcome'])

y=data.Outcome

# %%
x.head(2)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness    Insulin   BMI  \
# 0            6    148.0           72.0           35.0  79.799479  33.6
# 1            1     85.0           66.0           29.0  79.799479  26.6
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31

# %%
y.head(2)
# Out:
# 0    1
# 1    0
# Name: Outcome, dtype: int64

# %%
#Lets see how feature are related to class
plt.figure(figsize=(15,20))
plotnumber = 1
for column in x:
    if plotnumber <=9:
        ax=plt.subplot(3,3,plotnumber)
        sns.stripplot(x=y,y=x[column])
    plotnumber +=1
plt.show()

# %%
#In my way . i think Our graph looking better
#We are ready to make model using Logistic Regression
#Lets import Logistics Rergession Algorithms

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix,accuracy_score,roc_curve,roc_auc_score

# %%
#Lets stardize our data

# %%
scaler=StandardScaler()

# %%
x_scaler=scaler.fit_transform(x)

# %%
x_scaler
# Out:
# array([[ 0.660667  ,  1.21489459,  0.01270591, ...,  0.36951254,
#          0.95856707,  1.40749112],
#        [-0.88088934, -1.05394332, -0.54108391, ..., -0.71217016,
#         -0.20856304, -0.1731259 ],
#        [ 1.27728954,  2.4753601 , -0.72568051, ..., -1.2221063 ,
#          1.14886003, -0.08993553],
#        ...,
#        [ 0.35235574,  0.24253549,  0.01270591, ..., -0.7739806 ,
#         -0.65680866, -0.25631627],
#        [-0.88088934,  0.42260199, -1.09487373, ..., -0.17132881,
#         -0.2170205 ,  1.15792001],
#        [-0.88088934, -0.76583692, -0.1718907 , ..., -0.12497098,
#         -0.3607974 , -0.83864886]])

# %%
#Lets check VIF

# %%
vif=pd.DataFrame()
vif['Score']=[variance_inflation_factor(x_scaler,i) for i in range(x_scaler.shape[1])]
vif['features']=x.columns
vif
# Out:
#       Score                  features
# 0  1.346586               Pregnancies
# 1  1.215331                   Glucose
# 2  1.279985             BloodPressure
# 3  1.287242             SkinThickness
# 4  1.050519                   Insulin
# 5  1.413239                       BMI
# 6  1.021498  DiabetesPedigreeFunction
# 7  1.554914                       Age

# %%
#In our not model there is no multicollinearty Problem.
#We are go to go

# %%
#Now check by Train Test

# %%
x_train,x_test,y_train,y_test=train_test_split(x_scaler,y,test_size=0.2,random_state= 94255)

# %%
lr=LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
#Lets check metrics

# %%
y_pred=lr.predict(x_test)

# %%
accuracy=accuracy_score(y_test,y_pred)
print(accuracy)
# Out:
# 0.8076923076923077

# %% [markdown]
# # Confusion Matrix

# %%
#Confusion Matrix

# %%
conf_mat=confusion_matrix(y_test,y_pred)
conf_mat
# Out:
# array([[68,  6],
#        [14, 16]])

# %%
#Lets check Manually Accuracy Formula - (TP+TN)/(TP+FP+FN+TN)

# %%
(84+28)/84+14+28+28
# Out:
# 71.33333333333334

# %%
#Similarly You can manually calulate precision/f1_score

# %%
from sklearn.metrics import classification_report

# %% [raw]
# print(classification_report(y_test,y_pred))

# %% [markdown]
# Q- What Kind of information they give ? (classfication report)
#
#
# Ans-If we used classification report it will give precision,recall,f1_score and accuracy . in other word it will all imp metrcis in shot.

# %% [markdown]
# ![image.png](attachment:36e712f7-7340-496c-b546-106daf585e1c.png)

# %%
#Roc Curve
fpr,tpr,threshold =roc_curve(y_test,y_pred)

# %%
#threshold[0] means no instances predicted (It should be read from 0 - MAX)
print('Threshold = ',threshold)
print('True Positive Rate = ',tpr)
print('False Positive Rate = ',fpr)
# Out:
# Threshold =  [inf  1.  0.]
# True Positive Rate =  [0.         0.53333333 1.        ]
# False Positive Rate =  [0.         0.08108108 1.        ]

# %%
plt.plot(fpr,tpr,color='orange',label='Roc')
plt.plot([0,1],[0,1],color='darkblue',linestyle='--')
plt.xlabel('Fasle Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('RecieVer Operating Characterstics (ROC)')
plt.legend()
plt.show()

# %%
#How Much area it is covering
auc_score=roc_auc_score(y_test,y_pred)
auc_score
# Out:
# 0.726126126126126

# %% [markdown]
# Q- What is the Significance of ROC Curve and AUC?
#
#
#
#
#
#
# Ans- In real life we create a various models using different algorithms that we can use for classification purpose . we use AUC to determie which model is the best one  to use for a given dataset .suppose  we have created Logistic Regression . SVM as well as a clustering model for classification purpose . we will calculte AUC for all the values will be the best model to use.

# %% [markdown]
# # Advantage of Logistic Regression
#
#
# - It is very simple and easy to implement
#
#
# - The output is more informative than other classification algorithms
#
#
# - It express the relationship between independent and dependent  variables
#
#
#
# - Very effective with linearly separable data.
#
#
#
#
# # Disadvantage of Logistic Regression
#
#
#
# - Not effective with data which are not linearly separable
#
#
#
# - Not as powerfull as other classification
#
#
#
# - Multiclass classification are much easier to do with other algorithms than losgistic regression.
#
#
#
#
# - It can only predict categorical outcomes
#
#
#
# - Not effective the labels are more than two
#
#
#
#
# - Logistic Regression is very good for binary classification.

# %%
#Nest Model in KNN - K Nearesr Neighbour

# %%
#AI Engineer - Saurav
#Date - 8 May 2024
#Time - 16:14
