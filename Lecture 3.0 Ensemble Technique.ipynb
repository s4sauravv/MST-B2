# %% [markdown]
# # Ensemble Technique
# # Date - 18-04-2024

# %% [markdown]
# # Ensemble Technique - >
# We regularly come across many games show on television and you must have noticed an option of 'Audiance Poll' most of the times a contestent goes with the option which has the highest vote from the audiance and most of the times they win. we can generalize this in real life as well where taking opinions from a majority of people is much more preferred than the opinion of a single person. Ensembles technique has a similar underlying idea where we aggregate predictions from a group of a predictors . which may be classifier or regressor . and most of the time the prediction is better than the one obtained using a single predictor such algorithm are called ensemble methods and such predictors are called ensembles.
#
#
#
# Let Suppose we have 'n' predictors : z1,z2,z3...., zn with a standard deviation of σ
#
#
# var(z) = σ^2
#
#
# If we use single predictors z1,z2,z3....zn the variance associated with each will be σ2 but the expected value will be the average of all the predictors.
#
#
#
# Lets Consider the average of the predictors .
#
#
#
# Lets consider the average of the predictors.
#
#
# μ=(z1+z2+z3+....+zn)/n
#
#
#
#
# If we use μ as the predictor then the expected values still remains the same but see the variance now :
#
#
# variance (μ)=σ^2/n
#
#
#
#
# So the expected value remain 'μ' but  variance decreases when we use average of all the predictors .
#
#
#
#
# This is why taking means it preferred over using single predictors .
#
#
#
#
# Ensemble method take multiple small models and combine their prediction to obtain a more powerfull predictive power .
#
#
#
#
# There are few very popular ensemble Techniques which we will ralk about in details such as Bagging , Boosting , Stacking etc.

# %% [markdown]
# # Ensemble Technique -
#
#
#
# When i say ensemble approaches there are two types .
#
#
# 1- Bagging - In bagging we have couple of classifier algorithms.
#
#
#
# 2- Boosting  - Boosting also we are going to discuss couple of algorithm . we get into this boosting lates .
#
#
# So lets talk aboout Bagging.
#
#
#
#
#
# Q-  What is Ensemble Approach ?
#
# ensemble - You are going to combine multiple algorithm . you are going to build multiple algorithm and making one decision.
#
#
#
# Example - Bagging the best example is Let Say . Usually to decide the winner in reality show in dance competition so singing competition . So usually a Judges and audiance will be there earlier they use to give SMS number . So they use to audiance pole and public pole . because if only 3 Judges or 1 judge take a decision whatever comes to his mind he will take a decision so there is a chance  that he might be a biased who ever they like make them winner .
#
#
#
#
#  Suppose say 1 Judge means only one model whatever he decide that is final so may what if biased to a particular particapant possible  may be  he likes may be he relatives in the show . There is a possibility so what if take openion from multiple people the audiance so that may basically we will reduce that biasness . will reduce that overfitting problem so the low risk we are going to build a generalised model . so basically ensemble means . Suppose say 100 of audiance one person has individual model. every one going to vote . who are going to get majority vote he will be winner that is how basically we select the winners .
#
#
#
#
#
#  Same concept apply in the Bagging.
#
#
#
#  In Bagging let 100 audinace so we are going to build 100 model not individually ..
#
#
#
#
#  So that the simle and easiest intution behind this bagging.
#
#
#
#
#
#  Yes. Ensembles techniques are supervised machine learning that can be used for both classification and regression . Some are famous for classification and some are famous for regression . we will understand one by one so we are discussing bagging.

# %% [markdown]
# # Bagging is also called BootStrap Aggregations
#
#     --> Bagging (BootStrap Aggregation)

# %% [markdown]
# ![Screenshot%20%28250%29.png](attachment:Screenshot%20%28250%29.png)

# %% [markdown]
# - You got the concept . Now learn How they are going to decide on what basis - Let say.
#
# - Based on this all feature model need to predict he is going to pass or fail.
#
#
# - We have to build multiple models ? Multiple models meand can be KNN,DTree,LR,SVM any model.
#
#
# - Let say i am taking Decison Tree so i am going to build 5 Decison Tree Model.
#
#
#
#
# Q- How are we going to decide 5 or 10 or 100?
#
#
#
# Ans-  That we will see . That is a different Discussiion.

# %% [markdown]
# I am going to set this BootStrap = True . It means that (With ReplaceMent)
#
#
# Means -> Hey i have these many features so , i am going to pass few feature randomly to decision tree 1, let say test 1 score , attendence_% , github_profile , i dont know which feature i am going to pass here i have no clue model will decide everything in random . So based on 3 feature only Dtree will decide the candidate is going to pass or fail . That decision is made .
#
#
#
#
# -> Second Decision tree again it is going to pick randomly from all this feature .
#
#
#
#
#
#
# * With Replacement * -> Means that when a decision tree picks features, it can choose the same feature more than once. So, if it picks a feature, it might pick it again later. After each pick, the features are shuffled before the next selection.
#
#
#
#
# IN Regression - Same thing will be done but in regression we are not say pass or fail . regression is in terms of a number . First model say 3 LPA  Scond will 4.5 and so on.. then we take a mean .
#
#
#
#
#
# Q - How many features we can allow to the data for each and every algorithm and how many such decision tree can be built .5,10,20 that we will see .
#
#
#
#
# Ans - So we discuss about with replacement when it will happen when you say.
#
#
# BootStrap = True.
#
#
#
#
#
#
# Q - What happen when we say BootStrap = False ?
#
#
# Ans -  Then it called without Replacement means what , once we take decision tree . 3 features these 3 features  is gone it is not available for next Dtree .
#
#
#
#
#
#
#
# There is not provision to pick same even though it is randomly it can not pick . that there which are using in first Dtree . They are gone . it has to pick all together new feature and make a prediction that is what happen when you set BootStrap = False.
#
# and this is called Pasting (Without Replacement)

# %% [markdown]
# In reallife scenarios we dont have multiple different training set on which we can train our model separately and at the end  combine their result . Here , bootstrapping comes into picture . BootStrapping is a technique of sampling different sets of data from a given training set by using replacement . After bootstraping the training dataset . we train model on all the different sets and aggregate the resul . The technique is known as BootStrap Aggregation or Bagging.
#
#
#
#
#
#
# Bagging - Bagging is the type of ensembles technique in which a single training algorithm is used on different subsets of the training data where the subsets of the training data where the subset sampling is done with replacemennt (bootstrap) . once the algorithmis trained on all the subsets . then bagging makes the prediction by aggreagating all the prediction made by the algorithm on different subsets. In case of regression bagging prediction is simply the mean of all the prediction and in the case of classifer bagging prediction is the most frequent prediction (Majority Vote) among all the predictions.
#
#
#
#
# Bagging is also know as PARALLEL MODEL Since we run all models parallely and combine there result at the end .
#
#
#
#
#
#
# # Advantage of Bgging Model :-
#
# 1 - Bagging Significantly dereases the variance without increasing bias .
#
#
# 2 - Bagging Methods work so wee because of the diversity in the training data since the sampling is done by bootstraping.
#
#
#
# 3 - Also , if the training data sets is vey huge . it can save computational time by training model on relatively smaller data set and still can increases the accuracy of the model.
#
#
#
# 4- Works well with samll dataset as well.
#
#
#
# # Disadvantage of Bagging Model :-
#
#
# 1- The main diadvantage of bagging is that it imporves the accuracy of the model on the expense of the interpretability i.e  if a single tree was being used as the base model then it would have a more attractive and easily interpretable diagram but with use of bagging this interpretability gets lost.
#
# Example - If you were using a single decision tree, you could easily interpret its structure by visualizing the tree diagram. Each split and decision point would be clear, making it easier to understand how the model is making predictions. However, when using bagging, you're essentially combining multiple trees into one, which can make it harder to interpret the overall decision-making process. Instead of having a single clear tree diagram, you have to consider the combined output of many trees, which can be more complex to understand.
#
#
#
#
#
#
# # Pasting -
#
# - Pasting is an esemble technique similar to bagging with only difference being that there is no replacement done while sampling the training dataset . this cause less diversity in the sampled dataset and data ends up being correlated thats why bagging is more preffered than pasting in real scerarios .
#
#
#
#
# # Out of Bag Evaluation -
#
# - We build multiple models every model will give independent decision then we will go with a final decision based on the majority. So , whenvever they use the data they will get trained every thing will be so for the testing . so there is a small set of a data . Some portion of that data . i am keep a side . That i will use for a testing so that set of data called out of bag evaluation . All things happen internally . Some portion of data will never be sampled will never go to anything so that data used for the testing . that set of data is called out of bag evaluation . Because this models never trained on this and have not seen this so everything happen internally and directly come with a result other wise you have to do train test.
# - when creating each individual model, some data points are left out of the training set for that model. These data points constitute the out-of-bag (OOB) samples.
# - The usefulness of the out-of-bag evaluation comes from the fact that it provides an estimate of a model's performance without the need for a separate validation set or cross-validation.
# -  This can be particularly useful when you have limited data and want to make the most out of it by using it both for training and evaluating the model.
#
#
#
#
#
# - In bagging , when different samples are collected , no sample contains all the data but a fraction of the original dataset . There might be some data which are never sampled at all . The remaining data which are not sampled are called out of bag instances . Since the model never trains ovet these data . They can be used of evaluating the accuracy of the model by using these data forr prediction . we do not need validation set or cross validation and can used out of bag instances for that puprose.

# %% [markdown]
# #  Let See Pyhton implementation of Bagging .

# %% [markdown]
# We are going to deal with two algorithms -
#
#
# 1 - Bagging Classifier (Not Popular )
#
#
# 2 - Random Forest (Classification and Poplular algorithms)
#
#
#
#
# These both are part of bagging.

# %% [markdown]
# # Bagging Classifier - >
#
# In the bagging classifier we are not going to indepth we are not going to indepth we are not going to build a big project or anything.
#
#
#
#     I will compare one of the bagging algorithm . That is bagging classifier with some other      algorithm KNN and will match and see the difference  so that you will get clear idea .
#
#
#
#
# - Baggning and Boosting Part of ensemble .

# %% [markdown]
# # Python Implementation

# %% [markdown]
# #### K Nearest Neighbors Formula
# ![image.png](attachment:24df2fdf-4cee-4ca5-9898-f8fa290d7710.png)

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.neighbors import KNeighborsClassifier


import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.datasets import load_breast_cancer
dataset=load_breast_cancer()

x=dataset.data
y=dataset.target

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=4)

# %%
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train,y_train)
knn.score(x_test,y_test)
# Out:
# 0.8951048951048951

# %% [markdown]
# # Let Use Bagging Over KNN and see if our score improves.

# %%
bag_knn=BaggingClassifier(KNeighborsClassifier(n_neighbors=5),n_estimators=9,max_samples=0.7,bootstrap=True,oob_score=True)

# %%
base_estimator=logistic_reg

# %%
bag_knn.fit(x_train,y_train)
bag_knn.score(x_test,y_test)
# Out:
# 0.9090909090909091

# %% [markdown]
# - Great Our Score Significantly improved with use of bagging.
#
#
#
# - Let not use bootstarp and see the model accuracy ! Remember this is pasting.

# %%
pasting_knn= BaggingClassifier(KNeighborsClassifier(n_neighbors=5),n_estimators=9,max_samples=0.7,bootstrap=False,random_state=3)

# %%
pasting_knn.fit(x_train,y_train)
pasting_knn.score(x_test,y_test)
# Out:
# 0.8881118881118881

# %% [markdown]
# * The main Model is Bagging is random Foerst (It is popular ensemble approach and if i say overall in the classification still random forest is the best model the datascienctist community peoples still takes that this is the best.
#
#
#
# * But it has advantages and disadvantages as i mention time cost everything matters .

# %% [markdown]
# # Random Forest ->
#
# Decision Tree are one of such models which have low bias high variance we have studied that decision tree trend to overfit the data . So Bagging technique becomes a bery good solution for decreasing the variance in a decision tree . Insted of using a bagging model with underlying model as a decision tree , we can also use random forest which is more conveinient and well optimized for a decision tree . The main issue which bagging is that there  is not much independence among the sampled dataset i.e There is corellation . The advantage of random forest over bagging models is that the random forest  makes  a tweak in the working forest makes a tweak in the working algorithm of bagging model to decrease the correlation in trees . The idea is to introduce more randomness while creating trees which will help in reducing correlation.
#
#
# ![image.png](attachment:be6f1d54-d8ac-4fa3-9a59-9527bd3e9dd1.png)
#
#
# # Lets Understand how algorithm works for a random forest model.
#
#
#
# 1 - Just like in bagging different samples are collected from the training dataset using bootstraping.
#
#
#
# 2- On each sample we train our tree model and we allow the trees to grow with high depths.

# %% [markdown]
# # Problem Statement
#
#
# - To build an application to classify the patients to be healthy or suffering from cardiovascular disease based on the given attributes .

# %%
#Important Libs
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns


# Preprocessing , Normalizing 
from sklearn.preprocessing import StandardScaler

#Models

from sklearn.model_selection import train_test_split,GridSearchCV

from sklearn.ensemble import RandomForestClassifier

#Metrics 

from sklearn.metrics import accuracy_score,confusion_matrix,classification_report



import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('https://raw.githubusercontent.com/training-ml/Files/main/cardio_train.csv',sep=';')
df.head()
# Out:
#     id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0  988  22469       1     155    69.0    130     80            2     2      0
# 1  989  14648       1     163    71.0    110     70            1     1      0
# 2  990  21901       1     165    70.0    120     80            1     1      0
# 3  991  14549       2     165    85.0    120     80            1     1      1
# 4  992  23393       1     155    62.0    120     80            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       1       0
# 3     1       1       0
# 4     0       1       0

# %%
#Dataset Stats 
print(df.shape)
# Out:
# (69301, 13)

# %%
#All are int and float types . understand the stats of dataframe
df.describe()
# Out:
#                  id           age        gender        height        weight  \
# count  69301.000000  69301.000000  69301.000000  69301.000000  69301.000000
# mean   50471.480397  19468.786280      1.349519    164.362217     74.203027
# std    28563.100347   2467.261818      0.476821      8.205337     14.383469
# min      988.000000  10798.000000      1.000000     55.000000     10.000000
# 25%    25745.000000  17664.000000      1.000000    159.000000     65.000000
# 50%    50494.000000  19704.000000      1.000000    165.000000     72.000000
# 75%    75150.000000  21326.000000      2.000000    170.000000     82.000000
# max    99999.000000  23713.000000      2.000000    250.000000    200.000000
#
#               ap_hi         ap_lo   cholesterol          gluc         smoke  \
# count  69301.000000  69301.000000  69301.000000  69301.000000  69301.000000
# mean     128.829584     96.650092      1.366806      1.226447      0.088051
# ...

# %% [markdown]
# # Observation
#
# - No Missing Values
#
# - Assuming Age is in Number of Days
#
#
# - Outliers in Height
#
#
# - Outliers in systolic Blood Pressure ap_hi
#
#
#
# - Outliers in ap_lo
#
#
# - See cholesterol and glucose are binary will see in the further.

# %% [markdown]
# #  How to remove the Duplicates

# %%
#Drop ID  and Remove Duplicates 
df.drop('id',axis=1,inplace=True)


#Duplicates Removel 
df.drop_duplicates(inplace = True)

# %% [markdown]
# It is advised to remove the nominal data first then only will be able to drop duplicates it at all they exist.

# %%
df.shape
# Out:
# (69277, 12)

# %%
df.head()
# Out:
#      age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0  22469       1     155    69.0    130     80            2     2      0
# 1  14648       1     163    71.0    110     70            1     1      0
# 2  21901       1     165    70.0    120     80            1     1      0
# 3  14549       2     165    85.0    120     80            1     1      1
# 4  23393       1     155    62.0    120     80            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       1       0
# 3     1       1       0
# 4     0       1       0

# %%
plt.figure(figsize=(10,8),facecolor='red')
plotnumber=1
for column in df[['age','height','weight','ap_hi','ap_lo']]:
    if plotnumber <=6:
        ax=plt.subplot(2,3,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
    plotnumber +=1
plt.show()

# %% [markdown]
# How its Works
#
# # Z Distribution/Statistics
#
# Lets Tranform Our Model distribution in to Z Distribution (Standard Normal Distribution)
#
#
# Where mean=0 and Std =1
#
#
#
#
# ![Screenshot%20%28257%29.png](attachment:Screenshot%20%28257%29.png)

# %% [markdown]
# The normal Distribution we are converting into standard Normal Distribution our main objective is what to remove the outliers . For that we are doing circus . First Convert into Standard Normal Distribution.
#
#
#
#
# Q- How Standard Normal Distribution will help us .
#
# Ans- This will convert data such a way that the mean data will be zero and standard deviation is 1.  in such a way its going to convert.
#
#
#
# If you have any outliers so they will form extreme either this or this size +3 or beyond -3 but this is basically your whole data what ever the data you have we are converted into this manner  now i wanted to select maximum good data . So how i can select that.
#
#
# They will cover your data at some percentage .
#
#
#
# ![Screenshot%20%28259%29.png](attachment:Screenshot%20%28259%29.png)

# %% [markdown]
# Q - Is it Standard Like is it common like we need to select 3 standard deviation data .
#
#
# Ans- It is most of time 99% of time we use 3 std it not standard rule there  to use 3 std data .
#
#
#
#
# If you take 2 std lets assume this so how much data you going to miss around 5 % data you are going to miss . because it will cover only 95.45 %.

# %%
#With sid 3 lets see the stats 
#From scipy import stats 
#zscore=(x_mean)/std=>you have seen  this is Standard Scaler 

#Z=(x-mean)/std
from scipy.stats import zscore


z_score=zscore(df[['age','height','ap_hi','weight','ap_lo']])
abs_z_score=np.abs(z_score)#apply the formula and you get the scaled data 
filtering_entry=(abs_z_score < 3).all(axis=1)
df=df[filtering_entry]
df.describe()
# Out:
#                 age        gender        height        weight         ap_hi  \
# count  67360.000000  67360.000000  67360.000000  67360.000000  67360.000000
# mean   19466.779053      1.347268    164.374555     73.566278    126.164430
# std     2467.040240      0.476105      7.690310     13.195627     17.860035
# min    14275.000000      1.000000    140.000000     32.000000   -150.000000
# 25%    17660.000000      1.000000    159.000000     65.000000    120.000000
# 50%    19702.000000      1.000000    165.000000     72.000000    120.000000
# 75%    21324.000000      2.000000    170.000000     81.000000    140.000000
# max    23713.000000      2.000000    188.000000    117.000000    401.000000
#
#               ap_lo   cholesterol          gluc         smoke          alco  \
# count  67360.000000  67360.000000  67360.000000  67360.000000  67360.000000
# mean      81.286001      1.362010      1.223575      0.087159      0.053281
# ...

# %%
df.head()
# Out:
#      age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0  22469       1     155    69.0    130     80            2     2      0
# 1  14648       1     163    71.0    110     70            1     1      0
# 2  21901       1     165    70.0    120     80            1     1      0
# 3  14549       2     165    85.0    120     80            1     1      1
# 4  23393       1     155    62.0    120     80            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       1       0
# 3     1       1       0
# 4     0       1       0

# %% [markdown]
# Check How much Skewness we removed.

# %%
plt.figure(figsize=(20,15))
plotnumber=1
for column in df[['age','height','weight','ap_hi','ap_lo']]:
    if plotnumber<=6:
        ax=plt.subplot(2,3,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
    plotnumber +=1
plt.show()

# %% [markdown]
# 1- You can use correlation matrix and plot heatmap to check multicollinearity or correlation between all variable (Refer Decision Tree algo for heat map)
#
#
# # OR
#
#
# 2-You can use VIF to check if there is any multicollinearity(refer logistic regression for VIF)

# %%
#Cannot make out much from the above plots 
#Lets build Model

x=df.drop(columns=['cardio'])
y=df.cardio

# %% [markdown]
# # Split into Train Test

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.25,random_state=94255)

# %% [markdown]
# # Model Confidence/Accuracy

# %%
def metrics_score(cnn,x_train,x_test,y_train,y_test,train=True):
    if train:
        y_pred=cnn.predict(x_train)
        print("=================Training Score===============")
        print("Accuracy Score ==> ",accuracy_score(y_train,y_pred)*100)
    elif train==False:
        pred=cnn.predict(x_test)
        print("=================Testing Score===============")
        print("Accuracy Score ==> ",accuracy_score(y_test,pred)*100)
        print("Classification Report==> ", classification_report(y_test,pred))

# %% [markdown]
# # Initiate DecisionTreeClassifier with new parameter and Train

# %%
random_clf =RandomForestClassifier()

# %%
#Train the model
random_clf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
#Call the fucntion and pass dataset to check train and test score

# %%
metrics_score(random_clf,x_train,x_test,y_train,y_test,train=True)
metrics_score(random_clf,x_train,x_test,y_train,y_test,train=False)
# Out:
# =================Training Score===============
# Accuracy Score ==>  99.98218527315915
# =================Testing Score===============
# Accuracy Score ==>  71.49643705463184
# Classification Report==>                precision    recall  f1-score   support
#
#            0       0.71      0.74      0.72      8569
#            1       0.72      0.69      0.71      8271
#
#     accuracy                           0.71     16840
#    macro avg       0.72      0.71      0.71     16840
# weighted avg       0.72      0.71      0.71     16840

# %% [markdown]
# So , Our Model is Overfitted . Using GridSearchCV we will tune our parameter so here what parameter you can use . So this random Forest will use internally Decision Tree by default .
#
#
# When it is using a decision tree algorithm base estimator so obeviously the parameter are related to decision tree  only . Only One parameter we are going to add .one new parameter is . How much Decision Tree We want "n_estimator":[]

# %% [markdown]
# # Lets tune the parameter using GridSearchCV

# %%
#Random Forest Classifier 
params={'n_estimators':[13,15],
       'criterion':['entropy','gini'],
       'max_depth':[10,15],
       'min_samples_split':[10,13],
       'min_samples_leaf':[5,8]}

grd=GridSearchCV(random_clf,param_grid=params)
grd.fit(x_train,y_train)

print("Best_Params ==> ",grd.best_params_)
# Out:
# Best_Params ==>  {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 13, 'n_estimators': 15}

# %%
random_clf=grd.best_estimator_ #reinstantiating with best params
random_clf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=10, min_samples_leaf=5,
#                        min_samples_split=13, n_estimators=15)

# %%
metrics_score(random_clf,x_train,x_test,y_train,y_test,train=True)
metrics_score(random_clf,x_train,x_test,y_train,y_test,train=False)
# Out:
# =================Training Score===============
# Accuracy Score ==>  74.74069675376089
# =================Testing Score===============
# Accuracy Score ==>  73.48574821852732
# Classification Report==>                precision    recall  f1-score   support
#
#            0       0.71      0.80      0.75      8569
#            1       0.76      0.67      0.71      8271
#
#     accuracy                           0.73     16840
#    macro avg       0.74      0.73      0.73     16840
# weighted avg       0.74      0.73      0.73     16840

# %%
#Note - > You can improve the peformance by tweaking processing methods

# %% [markdown]
# # Lets Plot ROC AUC Curve ti choose best model.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve,roc_auc_score

from sklearn.metrics import roc_curve, RocCurveDisplay

# %%
from sklearn.metrics import r

# %%
lr=LogisticRegression()
knn=KNeighborsClassifier()
dt=DecisionTreeClassifier()
rf=RandomForestClassifier()

# %%
#Train Test Split

# %%
x=df.drop(columns=['cardio'],axis=1)
y=df.cardio

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.25,random_state=94062)

# %%
#Training with all classifiers
lr.fit(x_train,y_train)
rf.fit(x_train,y_train)
knn.fit(x_train,y_train)
dt.fit(x_train,y_train)
print("All Models are Trained")
# Out:
# All Models are Trained

# %% [markdown]
# # Lets Check ROC AUC Curve for the fitted Model
#
# - True Positive Rate(TPR)=Out OF 100 actual cardio patients how many our model predicted as cardio patients correctly (Higher The Better)
#
#
# - False Positive Rate (FPR)=How many people were predicted as cardio patients but in reality they were healthy (Lower the Better)
#
#
#
#
#
# Since it is difficult to evaluate the score based on only TPR and FPR data. There comes AUC.

# %%
plt.figure(figsize=(8, 6))

for clf, label in zip(classifiers, labels):
    y_score = clf.predict_proba(x_train)[:, 1]
    fpr, tpr, _ = roc_curve(y_train, y_score)
    auc = roc_auc_score(y_train, y_score)
    roc_display = RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=auc, estimator_name=f'{label} (AUC = {auc:.2f})')
    roc_display.plot(ax=plt.gca())

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves for Different Classifiers')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()

# %% [markdown]
# # How well our model on test data.

# %%
# Create the display object
disp = RocCurveDisplay.from_estimator(dt, x_test, y_test)

# Plot ROC curve for logistic regression
RocCurveDisplay.from_estimator(lr, x_test, y_test, ax=disp.ax_)

# Plot ROC curve for k-nearest neighbors
RocCurveDisplay.from_estimator(knn, x_test, y_test, ax=disp.ax_)

# Plot ROC curve for random forest
RocCurveDisplay.from_estimator(rf, x_test, y_test, ax=disp.ax_)

# Add legend
plt.legend(["Decision Tree", "Logistic Regression", "KNN", "Random Forest"], prop={'size': 11}, loc='lower right',)

# Show the plot
plt.show()
