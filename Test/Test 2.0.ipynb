# %% [markdown]
# # Statistics Test 1.0

# %% [markdown]
# Time - 2 Hr
#
#
# Total Marks = 60

# %%
All the best

# %% [markdown]
# # Multiple Choice Questions

# %% [markdown]
# Question 1
#
#
#
# ![image.png](attachment:bd70c7fe-06a0-45a5-b261-7490a8593fb8.png)

# %% [markdown]
# A -> 1 - α
#
# B -> 1 - β
#
# C -> α
#
# B -> p

# %%
Ans=

# %% [markdown]
# Question 2
#
# ![image.png](attachment:1a7c372e-8e6e-44f9-b7be-fc7927b2d458.png)

# %% [raw]
# A-> Different from 25%
#
# B-> Equal to 25%
#
# C-> Less than 25%
#
# D-> More than 25%

# %%
Ans=

# %% [markdown]
# Question 3
#
# ![image.png](attachment:4dcff95f-d7ae-43f1-93cc-2b337ef43d32.png)

# %% [raw]
# A-> Equal in number
#
# B-> Paired
#
# C-> Correlation
#
# D-> All of the above

# %%
Ans=

# %% [markdown]
# Question 4
#
# ![image.png](attachment:a8e0e027-85cb-4747-b824-53fdaea42c89.png)

# %% [raw]
# A-> Type-I error
#
# B-> Type-II error
#
# C-> Unbiased decision
#
# D-> Difficult to tell

# %%
Ans=

# %% [markdown]
# Question 5
#
# ![image.png](attachment:aee1e62e-c710-4afd-a15b-83b4d96c6a31.png)

# %% [markdown]
# A-> Null hypothesis
#
# B-> Statistical hypothesis
#
# C-> Research hypothesis
#
# D-> Simple hypothesis

# %%
Ans=

# %% [markdown]
# Question 6
#
#
# ![image.png](attachment:066fab01-612a-4acf-a450-c09d37595f67.png)

# %% [raw]
# A-> Decreased
#
# B-> Increased
#
# C-> Constant
#
# D-> Both (a) and (b)

# %%
Ans=

# %% [markdown]
# Question 7
#
# ![image.png](attachment:a65610fc-a011-4a7c-8386-84994c03bad6.png)

# %% [markdown]
# A-> Two-tailed test
#
# B-> Left-tailed test
#
# C-> Right-tailed test
#
# D->Neither (a), (b) and (c)

# %%
Ans=

# %% [markdown]
# Question 8
#
# ![image.png](attachment:c302f903-41b8-46c1-a92f-240f8e3516ec.png)

# %% [raw]
# A-> Eating cheese before bed gives you more nightmares.
#
# B-> Eating cheese before bed gives you fewer nightmares.
#
# C-> Eating cheese is linearly related to the number of nightmares you have.
#
# D-> The number of nightmares you have is not affected by eating cheese before bed.

# %%
Ans=

# %% [markdown]
# Question 9
#
# ![image.png](attachment:7d15e70e-f113-4433-a85a-edb7cda81d27.png)

# %%
A-> N

B-> n/N>5

C-> N(1-P)>5

D-> N>30

# %%
Ans=

# %% [markdown]
# Question 10
#
# ![image.png](attachment:c103aa88-43d4-4d8b-992a-5fa106d59afb.png)

# %% [raw]
# A-> Rejecting HO when HO is correct
#
# B-> Rejecting HO when H1 is correct
#
# C-> None of the options
#
# D-> Accepting HO when HO is correct

# %%
Ans=

# %% [markdown]
# Question 11
#
# ![image.png](attachment:8456c53e-7f1c-404f-a062-811f0991c482.png)

# %% [raw]
# A-> 5% of the time we will make an incorrect inference
#
# B-> 5% of the time we will say that there is a real difference when there is no difference (Type I error)
#
# C-> 95% of the time we will say that there is no difference when there is a difference (Type II error)
#
# D-> 95% of the time the null hypothesis will be correct

# %%
Ans->

# %% [markdown]
# Question 12
#
# ![image.png](attachment:eb451b28-1290-4dfe-a432-ec92370b4ef5.png)

# %% [raw]
# A-> t-test
#
# B->z-test
#
# C-> chi-square test (also written as x2-test)
#
# D-> f-test

# %%
ANS =

# %% [markdown]
# Question 13
#
# ![image.png](attachment:6f7afea3-cee2-4f3b-af80-2fb03a2b174f.png)

# %% [markdown]
# A-> Hypothesis
#
# B-> Hypothesis testing
#
# C-> Level of significance
#
# D-> Test statistic

# %%
Ans=

# %% [markdown]
# Question 14
#
# ![image.png](attachment:c25ba26c-cf30-469f-841c-9ea678380296.png)

# %% [raw]
# A-> The probability of a type I error is controlled by the selection of the level of significance α.
#
# B-> The probability of a type II error is controlled by the sample size (n).
#
# C-> The power of a test depends upon the sample size and the distance between the null hypothesis and the alternative hypothesis.
#
# D-> The p-value measures the probability that the null hypothesis is true.

# %%
Ans =

# %% [markdown]
# Question 15
#
# ![image.png](attachment:fe5d4f1f-085d-4595-9306-5e7c4cff9dcf.png)

# %% [raw]
# A-> Left-tailed test
#
# B-> Right-tailed test
#
# C-> Two-tailed test
#
# D-> Difficult to tell

# %%
Ans =

# %% [markdown]
# # Python Basic Exercise
#
# ### Solve any three

# %% [markdown]
# Que 1 -> You have a list a=[1,2,3,6,9,7,4,5,8], and you have to find the kth element from the list. This means I want to find the 2nd largest number from the list. Similarly, you have to create a function where I pass a number, say 4, and the function will return the 4th largest number from the list.

# %%
Sol->

# %% [markdown]
# Que 2-> you have a list [1,8,0,6,4,0,6,0,0,2,0], You need to shift all the zeros to the right , without using any inbuilt function.

# %%
Sol->

# %% [markdown]
# Que 3->Reverse a string without using any inbuilt function like slicing.

# %%
Sol-

# %% [markdown]
# Que 4-> To find common prefix in array of strings
#
# array= ['Abce','Abcjhgj','Abcf']
#
#
# The common prefix among the strings 'Abce', 'Abcjhgj', and 'Abcf' is 'Abc'. So, the common prefix is 'Abc'.

# %%
Sol->

# %% [markdown]
# Que 5- Given the list l = [1,2,0,1,2,0,0], I want the output to be ans = [0,0,0,2,2,1,1] without using any inbuilt function

# %%
Sol->

# %% [markdown]
# # Statistics Theory Question
#
# ### Any 4

# %% [markdown]
# Que 1- What is Central Limit Theoram ? Explain.

# %%
Ans=

# %% [markdown]
# Que 2- What is CDF(Comulative density function). Explain with mathematics.

# %%
Ans=

# %% [markdown]
# Que 3- What is Anova test. how we can calculate behind the scene ?

# %%
Ans=

# %% [markdown]
# Que 4-  What is Chi-Square test. how we will calculate behind the scene.

# %%
Ans=

# %% [markdown]
# Que 5-  What is the difference between inferential and descriptive statistics.

# %%
Ans=

# %% [markdown]
# Que 6- Explain any 2 distribution.

# %%
Ans =

# %% [markdown]
# # Statistics Mathematics  Question
#
# ## Any 2

# %% [markdown]
# Que 1 - if I generate heights for 1000 people from a normal distribution, what would be the probability for a new person to have a height of 70 inches using (CDF) then z-score table? take height in inches.
#
# #### Mean height (in inches) of the population
# mean_height = 66
#
# #### Standard deviation of heights (in inches) of the population
# std_dev_height = 3
#
#
# ##### Generate data using this code
# ###### Generate heights for 1000 people from a normal distribution
# heights = np.random.normal(mean_height, std_dev_height, 1000)))

# %%
Sol=

# %% [markdown]
# Que 2-  Suppose a fitness center manager anticipates the attendance for a particular yoga class throughout the week. Based on historical data and other factors, they estimate the expected attendance in numbers:
#
# ### Expected Attendance:
#
# Monday: 40
#
# Tuesday: 45
#
# Wednesday: 38
#
# Thursday: 50
#
# Friday: 55
#
# Saturday: 60
#
# Sunday: 65
#
# However, after the week concludes, the actual attendance is recorded:
#
#
#
# ### Observed (Actual) Attendance:
#
#
#
# Monday: 38
#
# Tuesday: 43
#
# Wednesday: 40
#
# Thursday: 48
#
# Friday: 52
#
# Saturday: 58
#
# Sunday: 62
#
# Ho: There is no significant difference between the expected and observed attendance for the yoga class throughout the week.
#
# Ha: There is a significant difference between the expected and observed attendance for the yoga class throughout the week.
#
# #### Use chi-square test *Statistical Tools*

# %%
Sol=

# %% [markdown]
# Que3 -> Calculate anova test
#
#
#
#
#
#     | Student_ID | Semester | Total_Marks |
#     |------------|----------|-------------|
#     | 1          | Fall     | 85          |
#     | 2          | Fall     | 78          |
#     | 3          | Fall     | 92          |
#     | 4          | Spring   | 88          |
#     | 5          | Spring   | 75          |
#     | 6          | Spring   | 82          |
#     | 7          | Summer   | 90          |
#     | 8          | Summer   | 86          |
#     | 9          | Summer   | 79          |
#
#
# Null Hypothesis (Ho): The average marks of students in each semester are approximately equal.
#
# Alternative Hypothesis (Ha): The average marks of students in at least one semester are different.

# %%
import pandas as pd

data = {
    'Student_ID': [1, 2, 3, 4, 5, 6, 7, 8, 9],
    'Semester': ['Fall', 'Fall', 'Fall', 'Spring', 'Spring', 'Spring', 'Summer', 'Summer', 'Summer'],
    'Total_Marks': [85, 78, 92, 88, 75, 82, 90, 86, 79]
}

df = pd.DataFrame(data)

print(df)
# Out:
#    Student_ID Semester  Total_Marks
# 0           1     Fall           85
# 1           2     Fall           78
# 2           3     Fall           92
# 3           4   Spring           88
# 4           5   Spring           75
# 5           6   Spring           82
# 6           7   Summer           90
# 7           8   Summer           86
# 8           9   Summer           79

# %%
Sol=

# %%
#Solution only submit in Github
