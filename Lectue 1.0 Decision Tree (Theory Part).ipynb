# %% [markdown]
# # Decision Tree

# %% [markdown]
# very intresting , very easy,simplest algorithm in the supervised machine learning .
#
#
#
# We are going to build tree . through the help of decision tree .we are going to take decision is based on a tree
#
#
#
#
# it is also called rule based algorithm
#
#
#
#
# its work on the if else principle ,(Greater then , Smaller then)
#
#
#
#
# in this decision tree what are all these name of boxex .
#
#
#
#
#
# ![Screenshot%20%28232%29.png](attachment:Screenshot%20%28232%29.png)

# %% [markdown]
# Decision Tree algorithm is one of the most versatile algorithms is which machine learning which can performed both classification and regression analysis . it is very powerfull and works great. with a complex dataset. A part from that . it is very easy to understand and read . That makes it more popular to use . when coupled with ensemble techniques . which we will learn very soon. it performs even better. As the name suggest , the algorithm work  by dividing the whole dataset into a tree -like structured based on some rules and conditions and then gives prediction based on those condition. Let understand the aaproach to decision tree with a basic scenerio . Suppose its friday night and you are not able to decide if you should go out or stay at home . Let that decision tree decide it for you.

# %% [markdown]
# Q - Which feature come at the root node ?
#
# Ans  - In order to over come this challenge we have some techniques is  Criterion.
#
#
#
# Criterion - >  With the help of couple. of criteria will be able to decide which feature should come first which should come second and third , fourth , fifth . that we are to do. deciding root node
#
#
# Let say we have 100 features the tree is grow to like anything we are going to build this tree . depth will increase like may 10000,20000 you dont know . it will take hours . it will take weeks you dont know .
#
#
# Q- Do we wait until last decision ? and we cant make decision in between .?
#
# Ans - So basically we want to make a decision in between mainly at some depth so that we can saving training time cost . So basically we cut this tree is call TREE PRUNING .
#
#
#
#
# ![Screenshot%20%28235%29.png](attachment:Screenshot%20%28235%29.png)
#
#
#
#
# Q - How are we going to pruning this ? at what depth ?
#
# Ans - At what depth model accuracy will be good .
#
#
# So that what we are going to discuss.
#
# TREE PRUNING   -    POST PRUNING     -      PRE TUNING
#
#
#
#
#
#
#
#
# So Overall these are the Tree Pruning .
#
#
# There are other techniques we will talk in the hyperparameter tuning.
#
#
# So that we are understanding how decision can be made we dont need wait until last moment to make decision . i can make a decision in between also.
#
#
#
#
#
# Post Pruning - Post Pruning . also knows as backword pruning is this process where the decision tree is generated first and all then the non significant branches  are removed cross validation set of data is used to check the effect of pruning and test wheather expanding a node will make an improvement or not .if any improvement is there is reduction in accuracy then the node not be expanded and should be converted in a leaf node.
#
#
#
# Pre Pruning - Pre Pruning also known as foreword pruning , stops the non significant branches from generating . it uses a condition to decide when should it terminate splitting of some of the branches prematurely as the tree is generated. .

# %% [markdown]
# So , we are learning abount a root node , the first node is root node , which feature should come as root node the feature should have highest information about the label means that feature should contribute higher .
#
#
# Q - so this is how we are going to get this information .
#
#
#
# Ans -  Through some criterians .
#
#
# What are thode Criterians - 1 - Entropy
#                             2 - Ginni Indexing
#
#
#  Entropy - So one i mention highest information which feature have providing highest information about labels . so that is we will be able to find that using entropy.
#
#
#  ![Screenshot%20%28236%29.png](attachment:Screenshot%20%28236%29.png)

# %% [markdown]
# ![Screenshot%20%28237%29.png](attachment:Screenshot%20%28237%29.png)

# %% [markdown]
# Ginni Impurity  - it will work little opposite of entropy is meaning is going to same  only.
#
#
#
# Ginni indexing what happen it will check each and every feature . and it will check how much impurity each features has .
#
# Impurity means what ?
#
#
# How much non sense data . techincall we called as  a Ginni Impurity.
#
#
# means less the impurity more then information.
#
# Gain(T.X)= Entropy(T)-Entropy(T.X)

# %% [markdown]
# In entropy we can find highest information gain.
#
#
#
# in the ginni indexing we can find ginni impurities. which feature have less impurities it will provide you each feature impurities in terms of an number. so which ever is having less impurities so that is going to root node.

# %% [markdown]
# Q - Ginni and Entropy which one is best ?
#
#
#
# Ans  - We are going to use one of them. Then why there are two ?
#
# every dataset have different information we dont know wheather entropy is best to decide feature or ginni indexing is best . we have no clue but we know there are two.
#
#
#
# So we are going to use hyperparameter tuning and ask gridsearch cv tell me out of this two which one is better

# %% [markdown]
# Q- If we dont mention anything Neither entropy neither ginni ?
#
#
# Ans -By default it will choose ginni . Why ? because in the intropy we have log tranformation because it takes more time . but in ginni indexing we dont have a log transformation its very very simple form.

# %% [markdown]
# Different Algorithms for Decision tree .
#
#
#
# 1  -  ID3 (Iterative Dichotomiser) :  It is one of the algorithm used to construct desicion tree for classification . It always accept only categorical data.
#
#
#
#
# 2 - C4.4 : Classification 4.5 . So it is an extension of ID3 algorithm. it was expecting both categorical and continious the problem was it is only use for classification.
#
#
#
#
# 3 - CART - Classification and Regression Algorithms (CART) -  It is the most popular algorithm used for constructing decision tree. it can be used for classification and regression and it will accept categorical data as well as continious data.

# %% [markdown]
# Q - How much difference when you use entropy and ginni indexing  ?
#
# Ans - Different will be very very minute . you can not make out . otherwise  both are okay only thing is entropy will take more time difference  wise you dont find much difference between entropy and ginni indexing.
#
#
#
#
#
# ![Screenshot%20%28238%29.png](attachment:Screenshot%20%28238%29.png)

# %% [markdown]
# # Advantage of Decision Tree :
#
#
# - It can be use for both regression and classification problem .
#
#
# - Decision Tree are very easy to to grasp as the rules of splitting is clearly mentioned
#
#
#
#
# - Complex Decision Tree models are very simple when visulaize it can be understood just by visualizing
#
#
#
# - Scaling and normalization are not needed.
#
#
#
#
#
# # Disadvantahe of Decision Tree
#
#
# - A small change in data can cause instability in the model because of the greedy approach.
#
#
# - Probablity of overfitting is very high for decision trees
#
#
#
# - It takes more time to train a decision tree model than ohter classification algorithms .

# %%
#AI Engineer - Saurav
#Date - 15-April-2024
#Time - 16:48 PM
